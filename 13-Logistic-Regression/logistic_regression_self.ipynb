# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
print("Setup successful")
# Out:
# Setup successful

# %%
train = pd.read_csv("titanic_trainb.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
train.isnull().sum(axis=0)
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(train.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='Survived',data=train)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
 print("The above plot shows that about roughly 550 passengers died, and about 350 passengers survived")
# Out:
# The above plot shows that about roughly 550 passengers died, and about 350 passengers survived

# %%
sns.countplot(x='Survived',data=train,hue='Sex')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
print("The graph shows that more males died and more females survived")
# Out:
# The graph shows that more males died and more females survived

# %%
print('Now let us look at the age distribution of passengers on the Titanic')
# Out:
# Now let us look at the age distribution of passengers on the Titanic

# %%
sns.displot(train.Age.dropna(),bins=30b)

# %%
print("Another easier way to plot this is, is by directly calling off the plot method out of the dataframe")
# Out:
# Another easier way to plot this is, is by directly calling off the plot method out of the dataframe

# %%
train['Age'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
print("Now let us look at the number of people with siblings and spouse")
# Out:
# Now let us look at the number of people with siblings and spouse

# %%
sns.countplot(x='SibSp',data=train)
# Out:
# <Axes: xlabel='SibSp', ylabel='count'>

# %%
print("It seems that more single people died :( Poor souls!")
# Out:
# It seems that more single people died :( Poor souls!

# %%
train['Fare'].hist()
# Out:
# <Axes: >

# %%
print("Let us now look at the passenger class and their counts")
# Out:
# Let us now look at the passenger class and their counts

# %%
sns.countplot(x='Survived',data=train,hue='Pclass')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
import cufflinks as cf
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 import cufflinks as cf
#
# ModuleNotFoundError: No module named 'cufflinks'
